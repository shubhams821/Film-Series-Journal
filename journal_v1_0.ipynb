# %%
shubhamst

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from collections import defaultdict

# Replace with the URL of your Letterboxd diary page
url = 'https://letterboxd.com/shubhamst/films/diary/'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all diary entries
entries = soup.find_all('tr', class_='diary-entry-row')

# Dictionary to store films organized by month
films_by_month = defaultdict(list)

for entry in entries:
    # Extract the viewing date
    day_element = entry.find('td', class_='td-day')
    viewing_date = day_element.text.strip()

    # Extract the film title
    film_title_element = entry.find('h3', class_='headline-3')
    film_title = film_title_element.text.strip()

    # Extract the month and year from the entry's link (assuming it's part of the URL)
    date_link = day_element.find('a')['href']
    date_parts = date_link.split('/')[-4:]  # ['2024', '05', '23']
    year = date_parts[0]
    month_number = date_parts[1]

    # Convert month number to month name
    month_name = datetime.strptime(month_number, "%m").strftime("%B")
    review_link = entry.find('a', class_="edit-review-button has-icon icon-16 icon-edit")
    review = review_link.get('data-review-text')

    # Store the film entry in the corresponding month
    films_by_month[f"{month_name} {year}"].append({
        'date': viewing_date,
        'title': film_title,
        'review': review
    })

# Sort the months in reverse order
sorted_months = sorted(films_by_month.keys(), key=lambda x: datetime.strptime(x, "%B %Y"), reverse=False)

# Print the films organized by month
for month in sorted_months:
    print(f"\n{month}")
    for film in films_by_month[month]:
        print(f"{film['date']}: {film['title']}")

for month in sorted_months:
    for film in films_by_month[month]:
        print()
        print(f"{film['title']}\n{film['date']}-{month}\n\n{film['review']}")
        print()
# Out:
# April 2024
# 29: Defending Jacob
#
# May 2024
# 28: Wedding Daze
# 26: Civil War
# 25: Furiosa: A Mad Max Saga
# 24: Decision to Leave
# 23: The Batman
# 22: Kingdom of the Planet of the Apes
#
# June 2024
# 29: Kalki 2898-AD
# 18: Gone Girl
# 17: The Dark Knight Rises
# 12: Zero Dark Thirty
# 03: In the Mood for Love
#
# July 2024
# 28: Schindler's List
# 28: Violet Evergarden: Eternity and the Auto Memory Doll
# 27: Deadpool & Wolverine
# 27: Late Night with the Devil
# 21: Crazy, Stupid, Love.
# 21: Free Guy
# 20: Gladiator
# 20: Bhavesh Joshi Superhero
# 14: Maharaja
# 14: Vash
# 14: Life Is Beautiful
# 13: Se7en
#
# August 2024
# 17: Rebel Moon – Part Two: The Scargiver
# 17: Sympathy for Mr. Vengeance
# 15: Stree 2: Sarkate Ka Aatank
# 14: Rebel Moon – Part One: A Child of Fire
# 04: Malena
#
# Defending Jacob
# 29-April 2024
#
# *spoiler* By far one of the best series I have ever seen, can't get normal after watching the last scene when he take a drink and just sit in dark room.
#
#
# Wedding Daze
# 28-May 2024
#
#
#
#
# Civil War
# 26-May 2024
#
# That's what I really crave for when I really want to watch a slow pace, dark, sad cinema.
# Perfect combination of beautiful cinematography and artsy film.
# Great.
#
#
# Furiosa: A Mad Max Saga
# 25-May 2024
#
# A greatest saga ever, I saw the Fury Road almost 4-5 years ago, years of questions about sequel, then announcement to watching trailer.
# Years of madness, and all worth it at the big screen.
# And at last they showed a small clip, clearly visible it's charlize theron from the back, took my heart. A great director
# Thank You
#
#
# Decision to Leave
# 24-May 2024
#
# Very different/unique way of storytelling, kind of but feels boring after first half, but the ending is where the <b><i>heart</i></b> of the movie lies.
# Thank you.
#
#
# The Batman
# 23-May 2024
#
# Greatest Batman movie ever.
# Kind of regret that I didn't watched it on imax, or biggest screen possible.
# Was waiting for this moment for years, finally watched it and it didn't disappoint me at all. It's far far above any expectations. Thats why DC is the best in its storytelling.
# Thank You.
#
#
# Kingdom of the Planet of the Apes
# 22-May 2024
#
# Visually beautiful, and still the heart of the movie is in the same place.
# Though the last shot. Love it.
#
#
# Kalki 2898-AD
# 29-June 2024
#
# Greatest depiction of Mahabharata war, this feels like how i imagine Mahabharata.
# There are definitely some lows, but overall it feels great and Ashwatthama is the best part about the movie.
# Thank You
#
#
# Gone Girl
# 18-June 2024
#
# Great,
# Who would ever think that such a simple story could turn into this crazy story line, yeah only Fincher.
# Damn Good film
#
#
# The Dark Knight Rises
# 17-June 2024
#
# Greatest Trilogy Ever,
# Took 3 years to complete (my decision) and worth every single second to wait for the next part, great screenplay though i am not a big advocate for speed paced screenplay but this definitely is an exception. what a detailed screenplay every single dialogue is some kind of legend.
# Man i am a big fan of nolan.
# Finally not have to skip those post credit scenes from Dark Knight Rises ever.
#
# Thank You
#
#
# Zero Dark Thirty
# 12-June 2024
#
# Great storytelling,
# I mean what could you expect from a movie where everything is just dialogue, gravity of each situation is shown by dialogues and you pretty much feel it. This is where the experience of great director and writer comes.
# Thank You
#
#
# In the Mood for Love
# 03-June 2024
#
# The slowmo with background score feels surreal, i often didn't connect with such genre can clearly see this was a masterpiece of its time.
# The direction was more than an art.
# Thank you
#
#
# Schindler's List
# 28-July 2024
#
# This star or review doesn't define it's greatness,
# This is the greatest stories I have ever heard. And this movie perfectly depicts it into screen. Not going to forget this for a while.
# The scene where a bullet missed the child and that kid accept his destiny and keeps walking, the scene where kid tries to hide into dump, the scene where Schindler provides water.
#
# And here we come again, again a story of lost battle.
#
#
# Violet Evergarden: Eternity and the Auto Memory Doll
# 28-July 2024
#
# This is one of those stories where you forget the whole world and start wondering inside their world, this show has the innocence which only few stories could pull off. The writing is amazing you view the story from Dolls point of view and it's doesn't have any over the top, or some convience writing to hook you up for next part. You just watch it to feel the story how their world is. Their creator has has given the purest form of art.
# Thanks
#
#
# Deadpool & Wolverine
# 27-July 2024
#
# More like a Marvel movie than Deadpool or Wolverine.
#
#
# Late Night with the Devil
# 27-July 2024
#
# Few scenes of the movie were scary, but movie can't be whole scary with good story.
# Liked the way movie was created.
# Pretty great.
#
#
# Crazy, Stupid, Love.
# 21-July 2024
#
# Nice comedy movie, didn't saw the last twist coming.
#
#
# Free Guy
# 21-July 2024
#
# Thing about Ryan Reynolds is he chooses great film that has some deep meaning in it with comedy and things work out well but there might be missing something......still Pikachu and the Adam project are the best in this.
#
#
# Gladiator
# 20-July 2024
#
# Great flim,
# Really liked the story, and great plot. One of the great revenge story after long time.
#
#
# Bhavesh Joshi Superhero
# 20-July 2024
#
# Bhavesh Joshi
# True indian super hero movie, this is the kind of story I am inclined towards, where the starting of movie feels completely different when it ends. It's the journey more than a movie. The character development was awesome and story was way way better than any average movie.
# Thanks
#
#
# Maharaja
# 14-July 2024
#
#
#
#
# Vash
# 14-July 2024
#
# Loved the movie,
# Though there are some minor inconsistencies which I could feel cause I have been watching best movies in the world. But apart from that this is not what I expected. The ending though.
#
#
# Life Is Beautiful
# 14-July 2024
#
# Life is beautiful.
# A tale that truly depicts "beauty lies in the eye of beholder".
# I am not really a guy who can be pessimist at such situations but that's how life is. Great
#
#
# Se7en
# 13-July 2024
#
# The Classic.
# The movie start with a very high note, where it's clear that this is going to be awesome. The acting was beyond expectations. The story was fab. And the ending the ending took my heart.
# Thanks
#
#
# Rebel Moon – Part Two: The Scargiver
# 17-August 2024
#
# Not as good as part 1, but finally ends the story only untill next part announces, the action works for the movies the material is just so much less than part 1, and Synder cinematography too good.
#
#
# Sympathy for Mr. Vengeance
# 17-August 2024
#
# This is the most disturbed film watched in a while, Great film, great story, unexpected storyline and totally justifies the title.
#
#
# Stree 2: Sarkate Ka Aatank
# 15-August 2024
#
#
#
#
# Rebel Moon – Part One: A Child of Fire
# 14-August 2024
#
# Watched the directors cut, and it's better than i expected after hearing the reviews. So many moments to cheer up, and the dialogue too much heavy, so many missed dialogues due to complexity. But the Synder cinematography always works for me.
#
#
# Malena
# 04-August 2024

# %%
films_by_month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4b0f1f1b6308> in <cell line: 1>()
# ----> 1 films_by_month.sort()
#
# AttributeError: 'collections.defaultdict' object has no attribute 'sort'

# %%
datetime.months
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2c46564858b0> in <cell line: 1>()
# ----> 1 datetime.months
#
# AttributeError: type object 'datetime.datetime' has no attribute 'months'
